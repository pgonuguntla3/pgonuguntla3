# %% [markdown]
# <a href="https://colab.research.google.com/github/pgonuguntla3/pgonuguntla3/blob/main/Goodreads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
file_path = "goodreads_cleaned.csv"
df = pd.read_csv (file_path)
df
# Out:
#                                               bookTitle       authorName  \
# 0               The Hunger Games (The Hunger Games, #1)  Suzanne Collins
# 1     Harry Potter and the Order of the Phoenix (Har...     J.K. Rowling
# 2                                   Pride and Prejudice      Jane Austen
# 3                                 To Kill a Mockingbird       Harper Lee
# 4                                        The Book Thief     Markus Zusak
# ...                                                 ...              ...
# 9995                                        The Company   Robert Littell
# 9996                             Thanks for the Trouble    Tommy Wallach
# 9997                                           10 Dates  Emily     James
# 9998  The Heights of Perdition (The Divine Space Pir...    C.S.  Johnson
# 9999                                      The Timingila       Shon Mehta
#
#       average_rating num_ratings
# 0               4.34   8,693,386
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bookTitle       10000 non-null  object
#  1   authorName      10000 non-null  object
#  2   average_rating  9996 non-null   float64
#  3   num_ratings     9996 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 312.6+ KB

# %%
df = df.drop_duplicates()
df = df.dropna()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['num_ratings'] = df['num_ratings'].str.replace(',', '').astype(int)

# %%
# Visualize the distribution of average ratings
plt.figure(figsize=(10, 6))
sns.histplot(df['average_rating'], bins=30, kde=True)
plt.title('Distribution of Average Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Visualize the relationship between average rating and number of ratings
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='average_rating', y='num_ratings')
plt.title('Average Rating vs Number of Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Number of Ratings')
plt.show()

# %%
# Top 10 highly rated books
top_10_books = df.sort_values(by='average_rating', ascending=False).head(10)
print("\nTop 10 Highly Rated Books:")
print(top_10_books[['bookTitle', 'authorName', 'average_rating', 'num_ratings']])
# Out:
# Top 10 Highly Rated Books:
#                                               bookTitle  \
# 6435                                   Armée des ombres
# 5624                              Coeur pourri de laine
# 5605                                     Gris Ange 2014
# 9919                                    Patience's Love
# 5640                           Das geheimnis der blumen
# 6280              Obscured Darkness (Family Secrets #2)
# 9761                     Anshuman krit Saral Vastu Gyan
# 7446  Elliptical door (A multifaceted overview) (US)...
# 7395  Rosto Inacabado (Pequenos segredos alquímicos)...
# 4247       A Day in the Life of Cowboy Mike and Winston
#
#                                   authorName  average_rating  num_ratings
# 6435  Lucio Agustine Rosenkreutz Crăciunescu            5.00           12
# 5624  Lucio Agustine Rosenkreutz Crăciunescu            5.00            9
# 5605  Lucio Agustine Rosenkreutz Crăciunescu            5.00            9
# ...

# %%
# Top 10 most rated books
top_10_most_rated_books = df.sort_values(by='num_ratings', ascending=False).head(10)
print("\nTop 10 Most Rated Books:")
print(top_10_most_rated_books[['bookTitle', 'authorName', 'average_rating', 'num_ratings']])
# Out:
# Top 10 Most Rated Books:
#                                               bookTitle           authorName  \
# 53    Harry Potter and the Sorcerer’s Stone (Harry P...         J.K. Rowling
# 9843            The Hunger Games (The Hunger Games, #1)      Suzanne Collins
# 0               The Hunger Games (The Hunger Games, #1)      Suzanne Collins
# 5                      Twilight (The Twilight Saga, #1)      Stephenie Meyer
# 3                                 To Kill a Mockingbird           Harper Lee
# 17                                     The Great Gatsby  F. Scott Fitzgerald
# 9                                The Fault in Our Stars           John Green
# 2745                                               1984        George Orwell
# 47                                                 1984        George Orwell
# 2                                   Pride and Prejudice          Jane Austen
#
#       average_rating  num_ratings
# 53              4.47     10085072
# ...
