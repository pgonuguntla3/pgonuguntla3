# %% [markdown]
# <a href="https://colab.research.google.com/github/pgonuguntla3/pgonuguntla3/blob/main/Alzheimers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
import os

# Define the directory path
directory = "alzheimer_s_disease_and_healthy_aging_data.csv"

# Iterate through the directory and its subdirectories
for dirname, _, filenames in os.walk(directory):
    # Iterate through the filenames
    for filename in filenames:
        # Check if the file is a CSV file
        if filename.endswith('.csv'):
            # Print the file path
            print(os.path.join(dirname, filename))

# %%
file_path = "alzheimer_s_disease_and_healthy_aging_data.csv"

# %%
# Read the CSV file with the correct file name
df = pd.read_csv('alzheimer_s_disease_and_healthy_aging_data.csv')

# Display the DataFrame
print(df)
# Out:
#                                           RowId  YearStart  YearEnd  \
# 0         BRFSS~2022~2022~42~Q03~TMC01~AGE~RACE       2022     2022
# 1         BRFSS~2022~2022~46~Q03~TMC01~AGE~RACE       2022     2022
# 2         BRFSS~2022~2022~16~Q03~TMC01~AGE~RACE       2022     2022
# 3         BRFSS~2022~2022~24~Q03~TMC01~AGE~RACE       2022     2022
# 4       BRFSS~2022~2022~55~Q03~TMC01~AGE~GENDER       2022     2022
# ...                                         ...        ...      ...
# 284137    BRFSS~2016~2016~55~Q15~TSC02~AGE~RACE       2016     2016
# 284138    BRFSS~2017~2017~56~Q45~TOC13~AGE~RACE       2017     2017
# 284139    BRFSS~2015~2015~56~Q42~TCC04~AGE~RACE       2015     2015
# 284140    BRFSS~2019~2019~54~Q46~TOC10~AGE~RACE       2019     2019
# 284141    BRFSS~2015~2015~56~Q02~TNC02~AGE~RACE       2015     2015
#
#        LocationAbbr   LocationDesc Datasource  \
# 0                PA   Pennsylvania      BRFSS
# 1                SD   South Dakota      BRFSS
# ...

# %%
df.isnull()
# Out:
#         RowId  YearStart  YearEnd  LocationAbbr  LocationDesc  Datasource  \
# 0       False      False    False         False         False       False
# 1       False      False    False         False         False       False
# 2       False      False    False         False         False       False
# 3       False      False    False         False         False       False
# 4       False      False    False         False         False       False
# ...       ...        ...      ...           ...           ...         ...
# 284137  False      False    False         False         False       False
# 284138  False      False    False         False         False       False
# 284139  False      False    False         False         False       False
# 284140  False      False    False         False         False       False
# 284141  False      False    False         False         False       False
#
#         Class  Topic  Question  Data_Value_Unit  ...  Stratification2  \
# ...

# %%
df.shape
# Out:
# (284142, 31)

# %%
# Drop rows with missing values
df_clean = df.dropna()

# Display the cleaned DataFrame
print(df_clean)
# Out:
#                                           RowId  YearStart  YearEnd  \
# 20943   BRFSS~2022~2022~22~Q40~TGC05~AGE~GENDER       2022     2022
# 20952   BRFSS~2022~2022~13~Q40~TGC05~AGE~GENDER       2022     2022
# 21005   BRFSS~2022~2022~41~Q40~TGC05~AGE~GENDER       2022     2022
# 21099     BRFSS~2022~2022~55~Q40~TGC05~AGE~RACE       2022     2022
# 21210     BRFSS~2022~2022~41~Q40~TGC05~AGE~RACE       2022     2022
# ...                                         ...        ...      ...
# 283486  BRFSS~2020~2020~54~Q40~TGC05~AGE~GENDER       2020     2020
# 283545    BRFSS~2020~2020~41~Q40~TGC05~AGE~RACE       2020     2020
# 283719  BRFSS~2020~2020~41~Q40~TGC05~AGE~GENDER       2020     2020
# 284004    BRFSS~2020~2020~49~Q40~TGC05~AGE~RACE       2020     2020
# 284103  BRFSS~2020~2020~39~Q40~TGC05~AGE~GENDER       2020     2020
#
#        LocationAbbr   LocationDesc Datasource       Class  \
# 20943            LA      Louisiana      BRFSS  Caregiving
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Example Plot')
plt.show()
